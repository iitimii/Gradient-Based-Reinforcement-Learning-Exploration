# %%
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from vpg import PolicyNetwork, VanillaPolicyGradient

# %%
env = gym.make("CartPole-v1", render_mode="human")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

policy_net = PolicyNetwork(state_dim, action_dim)
agent = VanillaPolicyGradient(env, policy_net)

all_rewards, avg_rewards = agent.train(num_episodes=1000)

env.close()
# Out:
# 2024-08-31 23:56:18.559 python[64533:5361010] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-08-31 23:56:18.560 python[64533:5361010] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# Episode 0, Total Reward: 54.0, Average Reward (last 100): 54.0
# Episode 50, Total Reward: 24.0, Average Reward (last 100): 28.901960784313726
# Episode 100, Total Reward: 25.0, Average Reward (last 100): 30.09
# Episode 150, Total Reward: 29.0, Average Reward (last 100): 40.68
# Episode 200, Total Reward: 58.0, Average Reward (last 100): 63.21
# Episode 250, Total Reward: 152.0, Average Reward (last 100): 99.87
# Episode 300, Total Reward: 101.0, Average Reward (last 100): 142.82
# Solved! Episode 341, Average Reward: 195.15

# %%
plt.figure(figsize=(12, 6))
plt.plot(all_rewards, label='Total Reward per Episode')
plt.plot(avg_rewards, label='Average Reward (last 100 episodes)')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Training Progress of Vanilla Policy Gradient on CartPole-v1')
plt.legend()
plt.show()
